# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('seaborn')

# %% [markdown]
# # 1. Introduction to Matplotlib
#
# This chapter introduces the Matplotlib visualization library and demonstrates how to use it with data.

# %% [markdown]
# ***The Figure object is a container that holds everything on the page, while the Axes object is the canvas that holds the data to visualize it.***

# %%
x = np.linspace(1,5)
sin_x = np.sin(x)
log_x = np.log(x)
squared_x = np.square(x)
square_root_x = np.sqrt(x)

data = pd.DataFrame({'x': x,
                     'sin(x)':sin_x, 
                     'log(x)':log_x,
                     'squared(x)': squared_x,
                     'sqrt(x)': square_root_x})

# %% [markdown]
# ### Adding data to an Axes object
# ax.plot(df [ 'x_colummn_name' ],
# 		df [ 'y_column_name' ])
#
# ### Adding and choosing markers
# ax.plot(df [ 'x_colummn_name' ], df [ 'y_column_name' ], **marker="o"**)
#
# https://matplotlib.org/stable/api/markers_api.html
#
# ### Setting the linestyle
# ax.plot(df [ 'x_colummn_name' ], df [ 'y_column_name' ], marker="o", **linestyle="--"**)
#
# https://matplotlib.org/stable/api/
#
# ### Choosing Color
# ax.plot(df [ 'x_colummn_name' ], df [ 'y_column_name' ], marker="o", linestyle="--", **color="r"**)
#
# ### Customizing the axes labels
# ax.set_xlabel("Desired_name")
#
# ax.set_ylabel("Desired_name")
#
# ### Adding a title
# ax.set_title("Title_of_Interest")
#
# ***Don't forget the plt.show() function***

# %%
fig, ax = plt.subplots()

ax.plot(data['x'], data['sin(x)'], linestyle=None, color="b")
ax.plot(data['x'], data['sin(x)'] * 2, marker="v", linestyle="--", color="r")
ax.plot(data['x'], data['sin(x)'] * 3, marker="o", linestyle="--", color="y")

ax.set_xlabel("x")
ax.set_ylabel("sin(x)")

ax.set_title("Sin Function")

plt.show()

# %% [markdown]
# ### Small Multiples
#
# fig, ax = plt.subplots(number_of_rows, number_of_columns)

# %%
fig, ax = plt.subplots(2, 1)
plt.show()

# %%
# Sample
fig, ax = plt.subplots(2, 1)

ax[0].plot(data['x'], data['sin(x)'], linestyle="--", color="b")
ax[0].plot(data['x'], data['sin(x)'] * 2, color="r")
ax[0].plot(data['x'], data['sin(x)'] * 3, color="y")
ax[0].set_ylabel("sin(x)")
ax[0].set_title("Sin and Log Functions")

ax[1].plot(data['x'], data['log(x)'], linestyle="--", color="b")
ax[1].plot(data['x'], data['log(x)'] * 2, color="r")
ax[1].plot(data['x'], data['log(x)'] * 3, color="y")
ax[1].set_ylabel("log(x)")
ax[1].set_xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ### Sharing the y-axis range
# Just add the parameter **sharey** and set it to **True** | **sharey=true**

# %%
fig, ax = plt.subplots(2, 1, sharey=True)

ax[0].plot(data['x'], data['sin(x)'], linestyle="--", color="b")
ax[0].plot(data['x'], data['sin(x)'] * 2, color="r")
ax[0].plot(data['x'], data['sin(x)'] * 3, color="y")
ax[0].set_ylabel("sin(x)")
ax[0].set_title("Sin and Log Functions")

ax[1].plot(data['x'], data['log(x)'], linestyle="--", color="b")
ax[1].plot(data['x'], data['log(x)'] * 2, color="r")
ax[1].plot(data['x'], data['log(x)'] * 3, color="y")
ax[1].set_ylabel("log(x)")
ax[1].set_xlabel("x")
# Out:
# Text(0.5, 0, 'x')

# %% [markdown]
# ### Sharing the x-axis range
# Just add the parameter **sharex** and set it to **True** | **sharex=true**

# %%
fig, ax = plt.subplots(2, 2, sharex=True)

# Upper left
ax[0,0].plot(data['x'], data['log(x)'], linestyle="--", color="b")
ax[0,0].plot(data['x'], data['log(x)'] * 2, color="r")
ax[0,0].plot(data['x'], data['log(x)'] * 3, color="y")
ax[0,0].set_ylabel("log(x)")
ax[0,0].set_xlabel("x")

#Lower left
ax[0,1].plot(data['x'], data['sin(x)'], linestyle="--", color="b")
ax[0,1].plot(data['x'], data['sin(x)'] * 2, color="r")
ax[0,1].plot(data['x'], data['sin(x)'] * 3, color="y")
ax[0,1].set_ylabel("sin(x)")
ax[0,1].set_xlabel("x")

#Upper right
ax[1,0].plot(data['x'], data['sqrt(x)'], linestyle="--", color="b")
ax[1,0].plot(data['x'], data['sqrt(x)'] * 2, color="r")
ax[1,0].plot(data['x'], data['sqrt(x)'] * 3, color="y")
ax[1,0].set_ylabel("sin(x)")
ax[1,0].set_xlabel("x")

#Lower right
ax[1,1].plot(data['x'], data['squared(x)'], linestyle="--", color="b")
ax[1,1].plot(data['x'], data['squared(x)'] * 2, color="r")
ax[1,1].plot(data['x'], data['squared(x)'] * 3, color="y")
ax[1,1].set_ylabel("log(x)")
ax[1,1].set_xlabel("x")

plt.show()

# %% [markdown]
# # 2. Plotting time-series
# Time series data is data that is recorded. Visualizing this type of data helps clarify trends and illuminates relationships between data.
#
# To designate the index as a DateTimeIndex, you will use the parse_dates and index_col key-word arguments both to parse this column as a variable that contains dates and also to designate it as the index for this DataFrame.

# %%
# Read the data from file using read_csv
climate_change = pd.read_csv('datasets/climate_change.csv', parse_dates=True, index_col="date")
climate_change
# Out:
#                co2  relative_temp
# date
# 1958-03-06  315.71           0.10
# 1958-04-06  317.45           0.01
# 1958-05-06  317.50           0.08
# 1958-06-06     NaN          -0.05
# 1958-07-06  315.86           0.06
# ...            ...            ...
# 2016-08-06  402.27           0.98
# 2016-09-06  401.05           0.87
# 2016-10-06  401.59           0.89
# 2016-11-06  403.55           0.93
# 2016-12-06  404.45           0.81
#
# [706 rows x 2 columns]

# %% [markdown]
# #### Plotting time-series data

# %%
climate_change.index
# Out:
# DatetimeIndex(['1958-03-06', '1958-04-06', '1958-05-06', '1958-06-06',
#                '1958-07-06', '1958-08-06', '1958-09-06', '1958-10-06',
#                '1958-11-06', '1958-12-06',
#                ...
#                '2016-03-06', '2016-04-06', '2016-05-06', '2016-06-06',
#                '2016-07-06', '2016-08-06', '2016-09-06', '2016-10-06',
#                '2016-11-06', '2016-12-06'],
#               dtype='datetime64[ns]', name='date', length=706, freq=None)

# %%
# Plotting the time-series data
fig, ax = plt.subplots()

ax.plot(climate_change.index, climate_change['co2'])

ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)')

plt.show()

# %%
fig, ax = plt.subplots()

# Add the time-series for "relative_temp" to the plot
ax.plot(climate_change.index, climate_change['relative_temp'])

# Set the x-axis label
ax.set_xlabel("Time")

# Set the y-axis label
ax.set_ylabel("Relative temperature (Celsius)")

# Show the figure
plt.show()

# %% [markdown]
# #### Using a time index to zoom in
# When a time-series is represented with a time index, we can use this index for the x-axis when plotting. We can also select a range of dates to zoom in on a particular period within the time-series using pandas' indexing facilities.

# %%
# Use plt.subplots to create fig and ax
fig, ax = plt.subplots()

# Create variable seventies with data from "1970-01-01" to "1979-12-31"
seventies = climate_change["1970-01-01":"1979-12-31"]

# Add the time-series for "co2" data from seventies to the plot
ax.plot(seventies.index, seventies["co2"])

# Show the figure
plt.show()

# %% [markdown]
# #### Plotting two time-series data together

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'])
ax.plot(climate_change.index, climate_change['relative_temp'])
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm) / Relative Temperature')
plt.show()

# Not good visualization

# %% [markdown]
# #### Using twin axes

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'], color='green')
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)', color='green')

ax2 = ax.twinx()
# This means the two axes shares the same x-axis,, but the y-axis is separate 
ax2.plot(climate_change.index, climate_change['relative_temp'], color="orange")
ax2.set_ylabel('Relative Temperature', color="orange")
plt.show()

# %% [markdown]
# #### Coloring the ticks
# ax.tick_params('y',colors='green')

# %%
fig, ax = plt.subplots()
ax.plot(climate_change.index, climate_change['co2'], color='green')
ax.set_xlabel('Time')
ax.set_ylabel('CO2 (ppm)', color='green')
ax.tick_params('y',colors='green')

ax2 = ax.twinx()
# This means the two axes shares the same x-axis,, but the y-axis is separate 
ax2.plot(climate_change.index, climate_change['relative_temp'], color="orange")
ax2.set_ylabel('Relative Temperature', color="orange")
ax2.tick_params('y',colors='orange')

plt.show()

# %% [markdown]
# #### A function that plots time-series

# %%
def plot_timeseries(axes, x, y, color, xlabel, ylabel):
    axes.plot(x, y, color=color)
    axes.set_xlabel(xlabel)
    axes.set_ylabel(ylabel, color=color)
    axes.tick_params('y', colors=color)

# %%
fig, ax = plt.subplots()
plot_timeseries(ax, climate_change.index, climate_change['co2'], 
                'orange', 'Time', 'CO2(ppm)')

ax2 = ax.twinx()
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 
                'green', 'Time', 'Relative Temperature (Celsius)')

plt.show()

# %% [markdown]
# #### Annotating Time-series data

# %%
fig, ax = plt.subplots()

# Plot the CO2 levels time-series in blue
plot_timeseries(ax, climate_change.index, climate_change['co2'], 'blue', "Time (years)", "CO2 levels")

# Create an Axes object that shares the x-axis
ax2 = ax.twinx()

# Plot the relative temperature data in red
plot_timeseries(ax2, climate_change.index, climate_change['relative_temp'], 'red', "Time (years)", "Relative temp (Celsius)")

# Annotate point with relative temperature >1 degree
ax2.annotate('>1 degree', xy=(pd.Timestamp('2015-10-06 00:00:00'), 1), xytext=(pd.Timestamp('2008-10-06 00:00:00'), -0.2),arrowprops={'arrowstyle': '->', 'color': 'gray'})

plt.show()

# %% [markdown]
# # 3. Quantitative comparisons and statistical visualizations
#
# Visualizations can be used to compare data in a quantitative manner. This chapter explains several methods for quantitative visualizations.

# %%
medals = pd.read_csv('datasets/medals_by_country_2016.csv', index_col=0)
medals
# Out:
#                Bronze  Gold  Silver
# United States      67   137      52
# Germany            67    47      43
# Great Britain      26    64      55
# Russia             35    50      28
# China              35    44      30
# France             21    20      55
# Australia          25    23      34
# Italy              24     8      38
# Canada             61     4       4
# Japan              34    17      13

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])
plt.show()

# %% [markdown]
# #### Interlude: rotate the tick labels
# ax.set_xticklabels(data.index, rotation=number_degrees)

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'])

ax.set_xticklabels(medals.index, rotation=60)
ax.set_ylabel("Number of Medals")
                   
plt.show()
# Out:
# C:\Users\JOHN PAUL\AppData\Local\Temp\ipykernel_5148\551047326.py:4: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=60)

# %% [markdown]
# #### Creating a stacked bar chart: Plotting with new added data

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label='Gold')
ax.bar(medals.index, medals['Silver'], 
       bottom=medals['Gold'])
ax.bar(medals.index, medals['Bronze'], 
       bottom=medals['Gold'] + medals['Silver'])

ax.set_xticklabels(medals.index, rotation=60)
ax.set_ylabel("Number of Medals")
                   
plt.show()
# Out:
# C:\Users\JOHN PAUL\AppData\Local\Temp\ipykernel_5148\2831185097.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=60)

# %% [markdown]
# #### Adding  a Legend

# %%
fig, ax = plt.subplots()
ax.bar(medals.index, medals['Gold'], label='Gold', color='blue')
ax.bar(medals.index, medals['Silver'], 
       bottom=medals['Gold'], label='Silver', color='orange')
ax.bar(medals.index, medals['Bronze'], 
       bottom=medals['Gold'] + medals['Silver'], label='Bronze', color='green')

ax.set_xticklabels(medals.index, rotation=90)
ax.set_ylabel("Number of Medals")
ax.legend()
                   
plt.show()
# Out:
# C:\Users\JOHN PAUL\AppData\Local\Temp\ipykernel_5148\2322068484.py:8: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(medals.index, rotation=90)

# %% [markdown]
# ### Quantitative comparisons: histograms

# %%
olympics_df = pd.read_csv('datasets/summer2016.csv', index_col=0)
mens_rowing = olympics_df[(olympics_df['Sex'] == 'M') & 
                          (olympics_df['Sport'] == 'Rowing')]
mens_gymnastics = olympics_df[(olympics_df['Sex'] == 'M') & \
                          (olympics_df['Sport'] == 'Gymnastics')]

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Height'])
ax.hist(mens_gymnastics['Height'])

ax.set_xlabel('Height (cm)')
ax.set_ylabel('Number of Observations')
plt.show()

# %% [markdown]
# #### Labels are needed

# %%
fig, ax = plt.subplots()
ax.hist(mens_rowing['Height'], label="Rowing")
ax.hist(mens_gymnastics['Height'], label="Gymnastics")

ax.set_xlabel('Height (cm)')
ax.set_ylabel('Number of Observations')
ax.legend()
plt.show()

# %% [markdown]
# #### Customizing histograms: setting the number of bins

# %%
fig, ax = plt.subplots()

bins=[150, 160, 170, 180, 190, 200, 210]

ax.hist(mens_rowing['Height'], label="Rowing", bins=bins)
ax.hist(mens_gymnastics['Height'], label="Gymnastics", bins=bins)

ax.set_xlabel('Height (cm)')
ax.set_ylabel('Number of Observations')
ax.legend()
plt.show()

# %% [markdown]
# #### Histogram with a histtype of step

# %%
fig, ax = plt.subplots()

bins=[150, 160, 170, 180, 190, 200, 210]

ax.hist(mens_rowing['Height'], label="Rowing", bins=bins, histtype="step")

ax.hist(mens_gymnastics['Height'], label="Gymnastics", bins=bins, histtype="step")

ax.set_xlabel('Height (cm)')
ax.set_ylabel('Number of Observations')
ax.legend()
plt.show()

# %%
fig, ax = plt.subplots()

# Plot a histogram of "Weight" for mens_rowing
ax.hist(mens_rowing['Weight'], label="Rowing", histtype='step', bins=5)

# Compare to histogram of "Weight" for mens_gymnastics
ax.hist(mens_gymnastics['Weight'], label="Gymnastics",histtype='step', bins=5)

ax.set_xlabel("Weight (kg)")
ax.set_ylabel("# of observations")

# Add the legend and show the Figure
ax.legend()
plt.show()

# %% [markdown]
# ### Statistical Plotting
# 1. Adding error bars to bar charts

# %%
fig, ax = plt.subplots()

ax.bar("Rowing",
      mens_rowing['Height'].mean(),
      yerr=mens_rowing['Height'].std())

ax.bar("Gymnastics",
      mens_gymnastics['Height'].mean(),
      yerr=mens_gymnastics['Height'].std())

ax.set_ylabel('Height (cm)')

plt.show()

# %% [markdown]
# 2. Adding boxplots

# %%
fig, ax = plt.subplots()
ax.boxplot([mens_rowing['Height'], 
           mens_gymnastics['Height']])
ax.set_xticklabels(['Rowing', 'Gymnastics'])
ax.set_ylabel('Height (cm)')

plt.show()

# %% [markdown]
# - The red line indicates the median
# - The edges of the box portion indicates the interquartile range of the data between the 25th and 75th of the data
# - The whiskers at the ends of the thin bars indicate one and a half times the size of the inter-quartile range beyond the 75th and 25th percentiles.
# - Points that appear beyond the whiskers are outliers. That means that they have values larger or smaller than what you would expect for 99 percent of the data in a Gaussian or normal distribution.
#
# For example, there are three unusually short rowers in this sample, and one unusually high gymnast, and one unusually high gymnast.

# %% [markdown]
# ### Scatter Plot
#
# Bar charts show us the values of one variable across different conditions, such as different countries. But what if you want to compare the values of different variables across observations? This is sometimes called a bi-variate comparison, because it involves the values of two different variables.
#
# **A standard visualization for bi-variate comparisons is a scatter plot.**

# %%
fig, ax = plt.subplots()

ax.scatter(climate_change['co2'], climate_change['relative_temp'])

ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (Celsius)")

plt. show ()

# %%
eighties = climate_change ["1980-01-01": "1989-12-31"]
nineties = climate_change ["1990-01-01": "1999-12-31"]

fig, ax = plt.subplots()

ax.scatter(eighties ["co2"], eighties["relative_temp"],
color="red", label="eighties")

ax.scatter (nineties ["co2"], nineties ["relative_temp"],
color="blue", label="nineties")

ax. legend()
ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (Celsius)")

plt.show()

# %% [markdown]
# #### Encoding a third variable by color
#
# Adding
#
# **c=climate_change.index**
#
# to the parametter of the scatter function

# %%
fig, ax = plt.subplots()

ax.scatter(climate_change['co2'], climate_change['relative_temp'], 
           c=climate_change.index)

ax.set_xlabel("CO2 (ppm)")
ax.set_ylabel("Relative temperature (Celsius)")

plt. show ()

# %% [markdown]
# # 4. Sharing visualizations with others
#
# This chapter shows you how to share your visualizations with others: how to save your figures as files, how to adjust their look and feel, and how to automate their creation based on input data.

# %% [markdown]
# ### Choosing a style
#
# https://matplotlib.org/stable/gallery/style_sheets/style_sheets_reference.html
#
# **plt.style.use('chosen_style')**
#
# Example:
#
# plt.style.use('seaborn')
#
# #### Guidelines for choosing plotting style
# - Dark backgrounds are usually less visible
# - If color is important, consider choosing colorblind-friendly options | "seaborn-colorblind" or tableau-colorblind10"
# - If it will be printed in black and white, use the "grayscale" style

# %% [markdown]
# ### Saving your visualizations
#
# #### 1. Size
# fig.set_size_inches([width,height])
#
# #### 2. 'png' format for good resolution
# fig.savefig("title.png")
#
# #### 3. 'jpg' format for storage-friendly resolution
# fig.savefig("title.jpg")
#
# #### 4. quality parameter for controlling the compression
# fig.savefig("title.jpg", quality=50)
#
# #### 5. if you want to edit the file afterwards using adobe, use 'svg'
# fig.savefig("title.svg")
#
# #### 6. the higher the dpi, the higher the density of the picture
# fig.savefig("title.png", dpi=300)

# %% [markdown]
# ### Automating figures from data
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
sports = olympics_df['Sport'].head(20).unique()
sports
# Out:
# array(['Rowing', 'Taekwondo', 'Handball', 'Wrestling', 'Gymnastics',
#        'Swimming', 'Basketball', 'Boxing', 'Volleyball', 'Athletics',
#        'Rugby Sevens'], dtype=object)

# %%
fig, ax = plt.subplots()

for sport in sports:
    sport_df = olympics_df[olympics_df['Sport']==sport]
    ax.bar(sport, sport_df['Height'].mean(),
          yerr=sport_df['Height'].std())
ax.set_ylabel('Height (cm)')

plt.xticks(rotation=90)


plt.show()
